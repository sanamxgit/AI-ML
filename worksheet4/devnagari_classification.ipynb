# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Devnagari Digit Classification using Fully Connected Network\n",
#       8     "\n",
#       9     "This notebook implements a Fully Connected Network (FCN) to classify Devnagari digits using TensorFlow and Keras."
#      10    ]
#      11   },
#      12   {
#      13    "cell_type": "code",
# ---> 14    "execution_count": null,
#      15    "metadata": {},
#      16    "source": [
#      17     "# Import required libraries\n",
#      18     "import os\n",
#      19     "import numpy as np\n",
#      20     "from PIL import Image\n",
#      21     "import tensorflow as tf\n",
#      22     "from tensorflow.keras import layers, models\n",
# ...
